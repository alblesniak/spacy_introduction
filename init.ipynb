# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If you imported a project with a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# There's no requirements.txt, so nothing to install. This is the case with most projects.

# %%
# %%bash
# # If you have previously installed any packages into this project, we re-install them here to restore your environment.
# if test -f .deepnote/requirements.txt
#   then
#     sed -i '/jupyter/d' .deepnote/requirements.txt
#     pip install -r .deepnote/requirements.txt
#   else echo "Seems like there is nothing to restore. Most likely, you haven't installed any extra packages so far."
# fi
# Out:
# Requirement already satisfied: attrs==19.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 1)) (19.3.0)
# Requirement already satisfied: backcall==0.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 2)) (0.1.0)
# Requirement already satisfied: bleach==3.1.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 3)) (3.1.5)
# Collecting blis==0.4.1
#   Downloading blis-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
# Collecting catalogue==1.0.0
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: certifi==2020.4.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 6)) (2020.4.5.1)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 7)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 8)) (0.10.0)
# Collecting cymem==2.0.3
#   Downloading cymem-2.0.3-cp37-cp37m-manylinux1_x86_64.whl (32 kB)
# Requirement already satisfied: decorator==4.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 10)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: docopt==0.6.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 12)) (0.6.2)
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 13)) (0.3)
# Requirement already satisfied: idna==2.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 14)) (2.9)
# Requirement already satisfied: importlib-metadata==1.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 15)) (1.6.0)
# Requirement already satisfied: ipykernel==5.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 16)) (5.3.0)
# Requirement already satisfied: ipython==7.14.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 17)) (7.14.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 18)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 19)) (7.5.1)
# Requirement already satisfied: jedi==0.17.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 20)) (0.17.0)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 21)) (2.11.2)
# Requirement already satisfied: joblib==0.15.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 22)) (0.15.1)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 23)) (3.2.0)
# Requirement already satisfied: kiwisolver==1.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 24)) (1.2.0)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 25)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 26)) (3.2.1)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 27)) (0.8.4)
# Collecting mock==4.0.2
#   Downloading mock-4.0.2-py3-none-any.whl (28 kB)
# Collecting murmurhash==1.0.2
#   Downloading murmurhash-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (19 kB)
# Requirement already satisfied: nbconvert==5.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 30)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.6 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 31)) (5.0.6)
# Requirement already satisfied: numpy==1.18.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 32)) (1.18.4)
# Requirement already satisfied: packaging==20.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 33)) (20.4)
# Requirement already satisfied: pandas==0.25.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 34)) (0.25.0)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 35)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 36)) (0.7.0)
# Collecting patsy==0.5.1
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Requirement already satisfied: pexpect==4.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 38)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 39)) (0.7.5)
# Requirement already satisfied: pipreqs@ git+https://github.com/deepnote/pipreqs.git@5c94fac42a8ddd19eabd75e3de8e84bb8120afd1 from git+https://github.com/deepnote/pipreqs.git@5c94fac42a8ddd19eabd75e3de8e84bb8120afd1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 40)) (0.4.8)
# Processing /datasets/spacy_pl_model/pl_spacy_model-0.1.0.tar.gz
# Collecting plac==1.1.3
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: pluggy==0.13.1 in /opt/venv/lib/python3.7/site-packages/pluggy-0.13.1-py3.7.egg (from -r .deepnote/requirements.txt (line 43)) (0.13.1)
# Collecting preshed==3.0.2
#   Downloading preshed-3.0.2-cp37-cp37m-manylinux1_x86_64.whl (118 kB)
# Requirement already satisfied: prometheus-client==0.7.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 45)) (0.7.1)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 46)) (3.0.5)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 47)) (0.6.0)
# Requirement already satisfied: Pygments==2.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 48)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 49)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 50)) (0.16.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 51)) (2.8.1)
# Requirement already satisfied: python-jsonrpc-server==0.3.4 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.3.4-py3.7.egg (from -r .deepnote/requirements.txt (line 52)) (0.3.4)
# Requirement already satisfied: python-language-server==0.30.0+39.g60b5005 in /opt/venv/lib/python3.7/site-packages/python_language_server-0.30.0+39.g60b5005-py3.7.egg (from -r .deepnote/requirements.txt (line 53)) (0.30.0+39.g60b5005)
# Requirement already satisfied: pytz==2020.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 54)) (2020.1)
# Requirement already satisfied: pyzmq==19.0.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 55)) (19.0.1)
# Requirement already satisfied: requests==2.23.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 56)) (2.23.0)
# Collecting scattertext==0.0.2.64
#   Downloading scattertext-0.0.2.64-py3-none-any.whl (6.9 MB)
# Requirement already satisfied: scikit-learn==0.23.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 58)) (0.23.1)
# Requirement already satisfied: scipy==1.4.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 59)) (1.4.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 60)) (1.5.0)
# Requirement already satisfied: six==1.14.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 61)) (1.14.0)
# Collecting spacy==2.2.4
#   Downloading spacy-2.2.4-cp37-cp37m-manylinux1_x86_64.whl (10.6 MB)
# Collecting srsly==1.0.2
#   Downloading srsly-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (185 kB)
# Collecting statsmodels==0.11.1
#   Downloading statsmodels-0.11.1-cp37-cp37m-manylinux1_x86_64.whl (8.7 MB)
# Requirement already satisfied: terminado==0.8.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 65)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 66)) (0.4.4)
# Collecting thinc==7.4.0
#   Downloading thinc-7.4.0-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
# Requirement already satisfied: threadpoolctl==2.0.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 68)) (2.0.0)
# Requirement already satisfied: tornado==6.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 69)) (6.0.4)
# Collecting tqdm==4.46.1
#   Downloading tqdm-4.46.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: traitlets==4.3.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 71)) (4.3.3)
# Requirement already satisfied: ujson==1.35 in /opt/venv/lib/python3.7/site-packages/ujson-1.35-py3.7-linux-x86_64.egg (from -r .deepnote/requirements.txt (line 72)) (1.35)
# Requirement already satisfied: urllib3==1.25.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 73)) (1.25.9)
# Collecting wasabi==0.6.0
#   Downloading wasabi-0.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: wcwidth==0.1.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 75)) (0.1.9)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 76)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 77)) (3.5.1)
# Requirement already satisfied: yarg==0.1.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 78)) (0.1.9)
# Requirement already satisfied: zipp==3.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 79)) (3.1.0)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel==5.3.0->-r .deepnote/requirements.txt (line 16)) (6.1.3)
# Requirement already satisfied: setuptools>=18.5 in /opt/venv/lib/python3.7/site-packages (from ipython==7.14.0->-r .deepnote/requirements.txt (line 17)) (46.4.0)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbconvert==5.6.1->-r .deepnote/requirements.txt (line 30)) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /opt/venv/lib/python3.7/site-packages (from widgetsnbextension==3.5.1->-r .deepnote/requirements.txt (line 77)) (7.0.0.dev0)
# Building wheels for collected packages: pl-spacy-model
#   Building wheel for pl-spacy-model (setup.py): started
#   Building wheel for pl-spacy-model (setup.py): finished with status 'done'
#   Created wheel for pl-spacy-model: filename=pl_spacy_model-0.1.0-py3-none-any.whl size=170055759 sha256=ca00748d9d9b6960c3626a437bde5362a86679f76e545b1a5fec5782ac2ca952
#   Stored in directory: /home/jovyan/.cache/pip/wheels/47/fc/81/8b78f42f00780dd8a3976730076f93250ca98ca5babeb24a14
# Successfully built pl-spacy-model
# Installing collected packages: blis, catalogue, cymem, mock, murmurhash, patsy, pl-spacy-model, plac, preshed, statsmodels, scattertext, srsly, tqdm, wasabi, thinc, spacy
# Successfully installed blis-0.4.1 catalogue-1.0.0 cymem-2.0.3 mock-4.0.2 murmurhash-1.0.2 patsy-0.5.1 pl-spacy-model-0.1.0 plac-1.1.3 preshed-3.0.2 scattertext-0.0.2.64 spacy-2.2.4 srsly-1.0.2 statsmodels-0.11.1 thinc-7.4.0 tqdm-4.46.1 wasabi-0.6.0
